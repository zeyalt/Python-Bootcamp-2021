# %% [markdown]
# # Python Bootcamp: Advent of Code (Day 8)

# %% [markdown]
# ## 1. Puzzle 1

# %% [markdown]
# ### 1.1 My Solution

# %%
def find_count_of_easy_numbers(data):
    
    output_values = [entry.split('| ')[1].strip() for entry in data]
    num_segments_in_easy_numbers = [2, 4, 3, 7]
    return len([digit for value in output_values for digit in value.split() if len(digit) in num_segments_in_easy_numbers])

if __name__ == "__main__":
    
    # Example data
    example_data = [
        'be cfbegad cbdgef fgaecd cgeb fdcge agebfd fecdb fabcd edb | fdgacbe cefdb cefbgd gcbe\n', 
        'edbfga begcd cbg gc gcadebf fbgde acbgfd abcde gfcbed gfec | fcgedb cgb dgebacf gc\n', 
        'fgaebd cg bdaec gdafb agbcfd gdcbef bgcad gfac gcb cdgabef | cg cg fdcagb cbg\n',
        'fbegcd cbd adcefb dageb afcb bc aefdc ecdab fgdeca fcdbega | efabcd cedba gadfec cb\n',
        'aecbfdg fbg gf bafeg dbefa fcge gcbea fcaegb dgceab fcbdga | gecf egdcabf bgf bfgea\n',
        'fgeab ca afcebg bdacfeg cfaedg gcfdb baec bfadeg bafgc acf | gebdcfa ecba ca fadegcb\n',
        'dbcfg fgd bdegcaf fgec aegbdf ecdfab fbedc dacgb gdcebf gf | cefg dcbef fcge gbcadfe\n',
        'bdfegc cbegaf gecbf dfcage bdacg ed bedf ced adcbefg gebcd | ed bcgafe cdgba cbgef\n',
        'egadfb cdbfeg cegd fecab cgb gbdefca cg fgcdab egfdb bfceg | gbdfcae bgc cg cgb\n',
        'gcafb gcf dcaebfg ecagb gf abcdeg gaef cafbge fdbac fegbdc | fgae cfgab fg bagce\n'    
    ]
    
    assert find_count_of_easy_numbers(example_data) == 26
    
    # Read input file
    with open('data/input.txt') as f:
        data = f.readlines()

    print(f"Number of times 1, 4, 7 and 8 appear: {find_count_of_easy_numbers(data)}")
# Out:
# Number of times 1, 4, 7 and 8 appear: 264

# %% [markdown]
# ## 2. Puzzle 2

# %% [markdown]
# ### 2.1 My Solution

# %%
def get_easy_numbers(list_of_signals):
    """Given a list of signals, return signals corresponding to the digits 1, 4, 7 and 8."""
    
    for item in list_of_signals:
        if len(item) == 2:
            one = item
        elif len(item) == 4:
            four = item
        elif len(item) == 3:
            seven = item
        elif len(item) == 7:
            eight = item

    return one, four, seven, eight

def get_three(list_of_signals, signal_for_seven):
    """Given a list of signals and the signal corresponding to seven, return the signal corresponding to the digit 3."""
    
    for signal in list_of_signals:
        if (len(signal) == 5) & (set(signal_for_seven).intersection(set(signal)) == set(signal_for_seven)):
            return signal
            break
        else:
            pass
        
def get_nine(list_of_signals, signal_for_four):
    """Given a list of signals and the signal corresponding to four, return the signal corresponding to the digit 9."""

    for signal in list_of_signals:
        if (len(signal) == 6) & (set(signal_for_four).intersection(set(signal)) == set(signal_for_four)):
            return signal
            break
        else:
            pass
        
def get_zero(list_of_signals, signal_for_seven):
    """Given a list of signals and the signal corresponding to seven, return the signal corresponding to the digit 0."""

    for signal in list_of_signals:
        if (len(signal) == 6) & (set(signal_for_seven).intersection(set(signal)) == set(signal_for_seven)):
            return signal
            break
        else:
            pass
        
def get_five(list_of_signals, signal_for_six):
    """Given a list of signals and the signal corresponding to six, return the signal corresponding to the digit 5."""

    for signal in list_of_signals:
        if (len(signal) == 5) & (set(signal).intersection(set(signal_for_six)) == set(signal)):
            return signal
            break
        else:
            pass
        
def get_mapping(list_of_signals):
    """Given a list of signals, return the mapping of each signal to each digits as a dictionary.
    
    For example, the sample input ['be', 'cfbegad', 'cbdgef', 'fgaecd', 'cgeb', 'fdcge', 'agebfd', 'fecdb', 'fabcd', 'edb'] 
    will generate the following mapping:
    
    {'agebfd': 0, 'be': 1, 'fabcd': 2, 'fecdb': 3, 'cgeb': 4, 'fdcge': 5, 'fgaecd': 6, 'edb': 7, 'cfbegad': 8, 'cbdgef': 9}
    """
    
    # Get signals for easy numbers first, i.e., 1, 4, 7, 8
    one, four, seven, eight = get_easy_numbers(list_of_signals)
    print(list_of_signals)
    mapping = {one: '1', four: '4', seven: '7', eight: '8'}
#     for k, v in mapping.items():
#         list_of_signals = [v if signal == k else signal for signal in list_of_signals]

    # Rodrigo's suggestion
    list_of_signals = [mapping.get(signal, signal) for signal in list_of_signals]
    
    # Get signal for not-so-easy numbers sequentially 
    three = get_three(list_of_signals, seven)
    list_of_signals = ['3' if signal == three else signal for signal in list_of_signals]

    nine = get_nine(list_of_signals, four)
    list_of_signals = ['9' if signal == nine else signal for signal in list_of_signals]

    zero = get_zero(list_of_signals, seven)
    list_of_signals = ['0' if signal == zero else signal for signal in list_of_signals]

    six = [signal for signal in list_of_signals if len(signal) == 6][0]
    list_of_signals = ['6' if signal == six else signal for signal in list_of_signals]

    five = get_five(list_of_signals, six)
    list_of_signals = ['5' if signal == five else signal for signal in list_of_signals]

    two = [signal for signal in list_of_signals if len(signal) == 5][0]
    list_of_signals = ['2' if signal == two else signal for signal in list_of_signals]

    # Save each mapping of signal to number as a dictionary
    mapping = dict()
    mapping[zero], mapping[one], mapping[two] = 0, 1, 2
    mapping[three], mapping[four], mapping[five] = 3, 4, 5
    mapping[six], mapping[seven], mapping[eight], mapping[nine] = 6, 7, 8, 9

    return mapping        

def get_output_value(mapping, output_values):
    """Given a mapping and a list of signals representing the output values, return the output value in integer form."""
    output = ''
    for value in output_values:
        for k, v in mapping.items():
            if set(value) == set(k):
                output += str(v)

    return int(output)        

def get_sum_of_output_values(list_of_signals, output_values):
    """Given a list of list of signals, return the total sum of all output values."""
    output_value = 0
    for idx, signal in enumerate(list_of_signals):
        mapping = get_mapping(signal)
        output_value += get_output_value(mapping, output_values[idx])
    return output_value


if __name__ == '__main__':
    
    # Example 1
    example_1 = [
        'acedgfb cdfbe gcdfa fbcad dab cefabd cdfgeb eafb cagedb ab | cdfeb fcadb cdfeb cdbaf\n'
    ]
    signals_and_output_1 = [line.strip().split(" | ") for line in example_1][0]
    signals_1 = [signals_and_output_1[0].split()]
    output_1 = [signals_and_output_1[1].split()]
    
    mapping_1 = get_mapping(signals_1[0])
    output_value_1 = get_output_value(mapping_1, output_1[0])
    
    assert mapping_1['eafb'] == 4
    assert mapping_1['acedgfb'] == 8
    assert mapping_1['cdfbe'] == 5
    assert mapping_1['cefabd'] == 9
    assert mapping_1['cagedb'] == 0
    assert mapping_1['cdfgeb'] == 6
    assert output_value_1 == 5353

    # Example 2
    example_2 = [
        'be cfbegad cbdgef fgaecd cgeb fdcge agebfd fecdb fabcd edb | fdgacbe cefdb cefbgd gcbe\n', 
        'edbfga begcd cbg gc gcadebf fbgde acbgfd abcde gfcbed gfec | fcgedb cgb dgebacf gc\n', 
        'fgaebd cg bdaec gdafb agbcfd gdcbef bgcad gfac gcb cdgabef | cg cg fdcagb cbg\n',
        'fbegcd cbd adcefb dageb afcb bc aefdc ecdab fgdeca fcdbega | efabcd cedba gadfec cb\n',
        'aecbfdg fbg gf bafeg dbefa fcge gcbea fcaegb dgceab fcbdga | gecf egdcabf bgf bfgea\n',
        'fgeab ca afcebg bdacfeg cfaedg gcfdb baec bfadeg bafgc acf | gebdcfa ecba ca fadegcb\n',
        'dbcfg fgd bdegcaf fgec aegbdf ecdfab fbedc dacgb gdcebf gf | cefg dcbef fcge gbcadfe\n',
        'bdfegc cbegaf gecbf dfcage bdacg ed bedf ced adcbefg gebcd | ed bcgafe cdgba cbgef\n',
        'egadfb cdbfeg cegd fecab cgb gbdefca cg fgcdab egfdb bfceg | gbdfcae bgc cg cgb\n',
        'gcafb gcf dcaebfg ecagb gf abcdeg gaef cafbge fdbac fegbdc | fgae cfgab fg bagce\n'    
    ]
    
    signals_and_output_2 = [line.strip().split(" | ") for line in example_2]
    signals_2 = [item[0].split() for item in signals_and_output_2]
    output_2 = [item[1].split() for item in signals_and_output_2]
    output_value_2 = get_sum_of_output_values(signals_2, output_2)
    
    assert output_value_2 == 61229

    # Input file
    with open('data/input.txt') as f:
        data = f.readlines()
    signals_and_output = [line.strip().split(" | ") for line in data]
    signals = [item[0].split() for item in signals_and_output]
    output = [item[1].split() for item in signals_and_output]
    
    print(f"Sum of all output values: {get_sum_of_output_values(signals, output)}")
# Out:
# ['acedgfb', 'cdfbe', 'gcdfa', 'fbcad', 'dab', 'cefabd', 'cdfgeb', 'eafb', 'cagedb', 'ab']
# ['8', 'cdfbe', 'gcdfa', 'fbcad', '7', 'cefabd', 'cdfgeb', '4', 'cagedb', '1']
#
# ['be', 'cfbegad', 'cbdgef', 'fgaecd', 'cgeb', 'fdcge', 'agebfd', 'fecdb', 'fabcd', 'edb']
# ['1', '8', 'cbdgef', 'fgaecd', '4', 'fdcge', 'agebfd', 'fecdb', 'fabcd', '7']
#
# ['edbfga', 'begcd', 'cbg', 'gc', 'gcadebf', 'fbgde', 'acbgfd', 'abcde', 'gfcbed', 'gfec']
# ['edbfga', 'begcd', '7', '1', '8', 'fbgde', 'acbgfd', 'abcde', 'gfcbed', '4']
#
# ['fgaebd', 'cg', 'bdaec', 'gdafb', 'agbcfd', 'gdcbef', 'bgcad', 'gfac', 'gcb', 'cdgabef']
# ['fgaebd', '1', 'bdaec', 'gdafb', 'agbcfd', 'gdcbef', 'bgcad', '4', '7', '8']
#
# ['fbegcd', 'cbd', 'adcefb', 'dageb', 'afcb', 'bc', 'aefdc', 'ecdab', 'fgdeca', 'fcdbega']
# ['fbegcd', '7', 'adcefb', 'dageb', '4', '1', 'aefdc', 'ecdab', 'fgdeca', '8']
#
# ['aecbfdg', 'fbg', 'gf', 'bafeg', 'dbefa', 'fcge', 'gcbea', 'fcaegb', 'dgceab', 'fcbdga']
# ['8', '7', '1', 'bafeg', 'dbefa', '4', 'gcbea', 'fcaegb', 'dgceab', 'fcbdga']
#
# ['fgeab', 'ca', 'afcebg', 'bdacfeg', 'cfaedg', 'gcfdb', 'baec', 'bfadeg', 'bafgc', 'acf']
# ['fgeab', '1', 'afcebg', '8', 'cfaedg', 'gcfdb', '4', 'bfadeg', 'bafgc', '7']
#
# ['dbcfg', 'fgd', 'bdegcaf', 'fgec', 'aegbdf', 'ecdfab', 'fbedc', 'dacgb', 'gdcebf', 'gf']
# ['dbcfg', '7', '8', '4', 'aegbdf', 'ecdfab', 'fbedc', 'dacgb', 'gdcebf', '1']
#
# ['bdfegc', 'cbegaf', 'gecbf', 'dfcage', 'bdacg', 'ed', 'bedf', 'ced', 'adcbefg', 'gebcd']
# ['bdfegc', 'cbegaf', 'gecbf', 'dfcage', 'bdacg', '1', '4', '7', '8', 'gebcd']
#
# ['egadfb', 'cdbfeg', 'cegd', 'fecab', 'cgb', 'gbdefca', 'cg', 'fgcdab', 'egfdb', 'bfceg']
# ['egadfb', 'cdbfeg', '4', 'fecab', '7', '8', '1', 'fgcdab', 'egfdb', 'bfceg']
#
# ['gcafb', 'gcf', 'dcaebfg', 'ecagb', 'gf', 'abcdeg', 'gaef', 'cafbge', 'fdbac', 'fegbdc']
# ['gcafb', '7', '8', 'ecagb', '1', 'abcdeg', '4', 'cafbge', 'fdbac', 'fegbdc']
#
# ['cdafg', 'dage', 'fgdaec', 'cdbfgae', 'cge', 'gcbdfa', 'fdceb', 'gfceab', 'ge', 'ecfgd']
# ['cdafg', '4', 'fgdaec', '8', '7', 'gcbdfa', 'fdceb', 'gfceab', '1', 'ecfgd']
#
# ['efgcabd', 'edacgf', 'gfaec', 'deg', 'dg', 'decga', 'dcfg', 'dbgafe', 'bfgcae', 'abced']
# ['8', 'edacgf', 'gfaec', '7', '1', 'decga', '4', 'dbgafe', 'bfgcae', 'abced']
#
# ['egacf', 'dfbeg', 'dec', 'efcgd', 'cfad', 'cfagde', 'fabcgde', 'dc', 'agbecf', 'bgdeac']
# ['egacf', 'dfbeg', '7', 'efcgd', '4', 'cfagde', '8', '1', 'agbecf', 'bgdeac']
#
# ['dc', 'cgefb', 'cdf', 'bdfgc', 'adbc', 'gafdec', 'cbagfd', 'gfbad', 'dbcagfe', 'gbedaf']
# ['1', 'cgefb', '7', 'bdfgc', '4', 'gafdec', 'cbagfd', 'gfbad', '8', 'gbedaf']
#
# ['dcbafg', 'gadeb', 'faegb', 'cfbga', 'ef', 'gfe', 'feca', 'aegfbc', 'cebgdf', 'dfabceg']
# ['dcbafg', 'gadeb', 'faegb', 'cfbga', '1', '7', '4', 'aegfbc', 'cebgdf', '8']
#
# ['bcf', 'adbcef', 'cbgdfe', 'dbceag', 'gcdbe', 'dcafg', 'egadcbf', 'fb', 'dgfcb', 'gebf']
# ['7', 'adbcef', 'cbgdfe', 'dbceag', 'gcdbe', 'dcafg', '8', '1', 'dgfcb', '4']
#
# ['dfge', 'dg', 'fbgce', 'ecgfdb', 'fcabdg', 'bafgec', 'cdg', 'cbdae', 'gecbd', 'ecgdabf']
# ['4', '1', 'fbgce', 'ecgfdb', 'fcabdg', 'bafgec', '7', 'cbdae', 'gecbd', '8']
#
# ['fadbg', 'badfe', 'faebcd', 'gab', 'ebfgad', 'bfceag', 'gfbcd', 'gade', 'adcebfg', 'ag']
# ['fadbg', 'badfe', 'faebcd', '7', 'ebfgad', 'bfceag', 'gfbcd', '4', '8', '1']
#
# ['gcfbd', 'dga', 'bfdcga', 'gafdbec', 'dcafg', 'defac', 'ag', 'adbfeg', 'acbg', 'bfdecg']
# ['gcfbd', '7', 'bfdcga', '8', 'dcafg', 'defac', '1', 'adbfeg', '4', 'bfdecg']
#
# ['efdab', 'cgadf', 'cbafd', 'fgbcda', 'ebgfdc', 'cfb', 'bc', 'gcba', 'cefgad', 'gfabcde']
# ['efdab', 'cgadf', 'cbafd', 'fgbcda', 'ebgfdc', '7', '1', '4', 'cefgad', '8']
#
# ['acgfe', 'gcedbf', 'fge', 'dbfacg', 'bgcfa', 'fcbaegd', 'ebga', 'eg', 'feacd', 'egabfc']
# ['acgfe', 'gcedbf', '7', 'dbfacg', 'bgcfa', '8', '4', '1', 'feacd', 'egabfc']
#
# ['cef', 'egcbd', 'fbage', 'cf', 'bacf', 'fecgba', 'fbadegc', 'fgdeab', 'fcbge', 'daegcf']
# ['7', 'egcbd', 'fbage', '1', '4', 'fecgba', '8', 'fgdeab', 'fcbge', 'daegcf']
#
# ['acdb', 'bdegc', 'fgced', 'dgb', 'fbdgace', 'agefcb', 'cegdab', 'dbgafe', 'bd', 'baegc']
# ['4', 'bdegc', 'fgced', '7', '8', 'agefcb', 'cegdab', 'dbgafe', '1', 'baegc']
#
# ['adbfce', 'bfgc', 'dfcebg', 'efbdg', 'cbefdga', 'bdcge', 'cb', 'afgbde', 'gceda', 'cbd']
# ['adbfce', '4', 'dfcebg', 'efbdg', '8', 'bdcge', '1', 'afgbde', 'gceda', '7']
#
# ['dafgbe', 'ecafg', 'edcbfa', 'fdcg', 'cef', 'fgade', 'cf', 'gecab', 'gdacebf', 'cedfag']
# ['dafgbe', 'ecafg', 'edcbfa', '4', '7', 'fgade', '1', 'gecab', '8', 'cedfag']
#
# ['acedgf', 'becdgfa', 'fgcae', 'fdgac', 'fdcgb', 'aged', 'gcfeba', 'ebfdca', 'ad', 'adc']
# ['acedgf', '8', 'fgcae', 'fdgac', 'fdcgb', '4', 'gcfeba', 'ebfdca', '1', '7']
#
# ['gefbd', 'beafgc', 'dabge', 'fgad', 'ag', 'bdcegf', 'agfebd', 'gba', 'acdeb', 'dgacebf']
# ['gefbd', 'beafgc', 'dabge', '4', '1', 'bdcegf', 'agfebd', '7', 'acdeb', '8']
#
# ['cdage', 'gcebfda', 'dea', 'bceag', 'de', 'bfcdae', 'egbd', 'egbdac', 'gebafc', 'cadfg']
# ['cdage', '8', '7', 'bceag', '1', 'bfcdae', '4', 'egbdac', 'gebafc', 'cadfg']
#
# ['becf', 'fcd', 'cabdg', 'gefdab', 'dbgcf', 'ebcgfd', 'cf', 'bgdfe', 'edfcag', 'egafdcb']
# ['4', '7', 'cabdg', 'gefdab', 'dbgcf', 'ebcgfd', '1', 'bgdfe', 'edfcag', '8']
#
# ['ec', 'dagcf', 'debag', 'eagdc', 'cfabed', 'eca', 'begc', 'bfeadg', 'dfcbaeg', 'bgeacd']
# ['1', 'dagcf', 'debag', 'eagdc', 'cfabed', '7', '4', 'bfeadg', '8', 'bgeacd']
#
# ['gace', 'egadbfc', 'bfecgd', 'dce', 'beadf', 'decfa', 'gcfdab', 'fcdaeg', 'ec', 'afgdc']
# ['4', '8', 'bfecgd', '7', 'beadf', 'decfa', 'gcfdab', 'fcdaeg', '1', 'afgdc']
#
# ['cfbge', 'ac', 'cea', 'fdeab', 'adfbgce', 'fabceg', 'dgfbce', 'abcef', 'acgb', 'afecdg']
# ['cfbge', '1', '7', 'fdeab', '8', 'fabceg', 'dgfbce', 'abcef', '4', 'afecdg']
#
# ['gfdcba', 'bcf', 'ecfdg', 'bc', 'baefgd', 'efbgac', 'caeb', 'aegfb', 'cebfg', 'badfegc']
# ['gfdcba', '7', 'ecfdg', '1', 'baefgd', 'efbgac', '4', 'aegfb', 'cebfg', '8']
#
# ['acg', 'cagbdfe', 'ca', 'fgcadb', 'agcebf', 'cegfd', 'acfgd', 'dacb', 'bdfga', 'feadgb']
# ['7', '8', '1', 'fgcadb', 'agcebf', 'cegfd', 'acfgd', '4', 'bdfga', 'feadgb']
#
# ['eabgfc', 'gfeac', 'dgaeb', 'ecgdfba', 'cba', 'eabgc', 'dfaegc', 'cb', 'cfgb', 'cdbeaf']
# ['eabgfc', 'gfeac', 'dgaeb', '8', '7', 'eabgc', 'dfaegc', '1', '4', 'cdbeaf']
#
# ['defgac', 'eabdcf', 'be', 'faedg', 'beag', 'bgdfe', 'gdebfa', 'ebf', 'bgcfd', 'bgdceaf']
# ['defgac', 'eabdcf', '1', 'faedg', '4', 'bgdfe', 'gdebfa', '7', 'bgcfd', '8']
#
# ['db', 'cfdbaeg', 'baecgd', 'dfbega', 'bdgaf', 'afebg', 'febd', 'adfcg', 'aebgfc', 'bdg']
# ['1', '8', 'baecgd', 'dfbega', 'bdgaf', 'afebg', '4', 'adfcg', 'aebgfc', '7']
#
# ['defbg', 'cbdfeg', 'dcbegaf', 'cbdf', 'cfe', 'begca', 'aegcfd', 'ecgbf', 'fc', 'agdebf']
# ['defbg', 'cbdfeg', '8', '4', '7', 'begca', 'aegcfd', 'ecgbf', '1', 'agdebf']
#
# ['ecdafb', 'dbf', 'bgdea', 'abcf', 'fdaegc', 'dabfe', 'fgecbd', 'fb', 'deafc', 'fdacbeg']
# ['ecdafb', '7', 'bgdea', '4', 'fdaegc', 'dabfe', 'fgecbd', '1', 'deafc', '8']
#
# ['fa', 'edfabg', 'bfacd', 'gcefdba', 'fba', 'agfc', 'cfedb', 'fagcdb', 'agdbce', 'adbcg']
# ['1', 'edfabg', 'bfacd', '8', '7', '4', 'cfedb', 'fagcdb', 'agdbce', 'adbcg']
#
# ['cfb', 'gcfbea', 'bacgfde', 'bc', 'geadfb', 'badc', 'bedfa', 'edbfc', 'ebadcf', 'gdfce']
# ['7', 'gcfbea', '8', '1', 'geadfb', '4', 'bedfa', 'edbfc', 'ebadcf', 'gdfce']
#
# ['cfd', 'gdeac', 'ecbfagd', 'cagdf', 'fagcbd', 'dafb', 'egcfab', 'bfgcde', 'fagbc', 'fd']
# ['7', 'gdeac', '8', 'cagdf', 'fagcbd', '4', 'egcfab', 'bfgcde', 'fagbc', '1']
#
# ['fcageb', 'fa', 'gfa', 'dbfa', 'begdfc', 'dcega', 'gdbfe', 'eafcdbg', 'fdaebg', 'afged']
# ['fcageb', '1', '7', '4', 'begdfc', 'dcega', 'gdbfe', '8', 'fdaebg', 'afged']
#
# ['feabc', 'gf', 'agdbe', 'gedbaf', 'fgbd', 'gfbea', 'becagd', 'fge', 'gadcfe', 'cdeagfb']
# ['feabc', '1', 'agdbe', 'gedbaf', '4', 'gfbea', 'becagd', '7', 'gadcfe', '8']
#
# ['dfebc', 'gedfcb', 'bcgfd', 'fde', 'dgbe', 'afcdge', 'dcgfab', 'ed', 'befca', 'fbcaedg']
# ['dfebc', 'gedfcb', 'bcgfd', '7', '4', 'afcdge', 'dcgfab', '1', 'befca', '8']
#
# ['ebafcd', 'acbd', 'cdebfg', 'ead', 'ecdbgaf', 'edacfg', 'efbag', 'da', 'fdebc', 'fedab']
# ['ebafcd', '4', 'cdebfg', '7', '8', 'edacfg', 'efbag', '1', 'fdebc', 'fedab']
#
# ['beadgc', 'bd', 'gcfba', 'adgce', 'cfedgab', 'bgd', 'cgfdae', 'agcbd', 'gadbfe', 'bdec']
# ['beadgc', '1', 'gcfba', 'adgce', '8', '7', 'cgfdae', 'agcbd', 'gadbfe', '4']
#
# ['fdecagb', 'bdafce', 'gbcfde', 'egcbd', 'ea', 'eadg', 'cbgae', 'gbceda', 'agcfb', 'aec']
# ['8', 'bdafce', 'gbcfde', 'egcbd', '1', '4', 'cbgae', 'gbceda', 'agcfb', '7']
#
# ['ca', 'fegabc', 'bdac', 'gecdfb', 'feabcd', 'cea', 'eafgd', 'aefdc', 'dgbaefc', 'edcfb']
# ['1', 'fegabc', '4', 'gecdfb', 'feabcd', '7', 'eafgd', 'aefdc', '8', 'edcfb']
#
# ['baegfdc', 'egb', 'fcage', 'bfcged', 'bfdea', 'gafecd', 'gbac', 'bg', 'caegbf', 'fegab']
# ['8', '7', 'fcage', 'bfcged', 'bfdea', 'gafecd', '4', '1', 'caegbf', 'fegab']
#
# ['fdabge', 'faedcbg', 'dfbea', 'gfcade', 'dfe', 'de', 'adbgfc', 'egdb', 'eafbc', 'badfg']
# ['fdabge', '8', 'dfbea', 'gfcade', '7', '1', 'adbgfc', '4', 'eafbc', 'badfg']
#
# ['bagcdfe', 'dfaceb', 'egdafb', 'facegd', 'cedbg', 'ga', 'dga', 'bgaed', 'fbag', 'bdfea']
# ['8', 'dfaceb', 'egdafb', 'facegd', 'cedbg', '1', '7', 'bgaed', '4', 'bdfea']
#
# ['cdbef', 'caebf', 'defabgc', 'ecfbag', 'cd', 'dfc', 'aced', 'dbegf', 'fcdbae', 'bdgfac']
# ['cdbef', 'caebf', '8', 'ecfbag', '1', '7', '4', 'dbegf', 'fcdbae', 'bdgfac']
#
# ['facbdg', 'dfgacbe', 'bfcgd', 'bcgedf', 'bgead', 'dec', 'gfdeac', 'fecb', 'egbcd', 'ce']
# ['facbdg', '8', 'bfcgd', 'bcgedf', 'bgead', '7', 'gfdeac', '4', 'egbcd', '1']
#
# ['abcef', 'ebfdc', 'dfagcb', 'dcbgef', 'ba', 'daeb', 'ceagf', 'dcaebfg', 'faecbd', 'fab']
# ['abcef', 'ebfdc', 'dfagcb', 'dcbgef', '1', '4', 'ceagf', '8', 'faecbd', '7']
#
# ['cbe', 'abecgf', 'be', 'gbacdf', 'dacfebg', 'eabcf', 'aegcdb', 'gabfc', 'gfbe', 'fdeac']
# ['7', 'abecgf', '1', 'gbacdf', '8', 'eabcf', 'aegcdb', 'gabfc', '4', 'fdeac']
#
# ['gfad', 'degab', 'fcgdbe', 'aeg', 'bfedg', 'abdgfe', 'gefacbd', 'ga', 'badce', 'fagceb']
# ['4', 'degab', 'fcgdbe', '7', 'bfedg', 'abdgfe', '8', '1', 'badce', 'fagceb']
#
# ['fgadbce', 'edbag', 'dgbcf', 'dabfg', 'fa', 'fdaceg', 'bacedg', 'faeb', 'bfadeg', 'gaf']
# ['8', 'edbag', 'dgbcf', 'dabfg', '1', 'fdaceg', 'bacedg', '4', 'bfadeg', '7']
#
# ['afde', 'cfadbg', 'gcdbe', 'bfdecag', 'ea', 'efbacg', 'abe', 'cfbda', 'debac', 'dacfbe']
# ['4', 'cfadbg', 'gcdbe', '8', '1', 'efbacg', '7', 'cfbda', 'debac', 'dacfbe']
#
# ['cefgad', 'bdcef', 'acdbfe', 'edbgfc', 'dae', 'beaf', 'bdacefg', 'ea', 'becda', 'bgcda']
# ['cefgad', 'bdcef', 'acdbfe', 'edbgfc', '7', '4', '8', '1', 'becda', 'bgcda']
#
# ['dfbaecg', 'eagfd', 'cf', 'acdf', 'bcgea', 'bcfdge', 'efc', 'dacfge', 'efacg', 'gbadfe']
# ['8', 'eagfd', '1', '4', 'bcgea', 'bcfdge', '7', 'dacfge', 'efacg', 'gbadfe']
#
# ['afec', 'daebgf', 'dfgcab', 'fcgeabd', 'gef', 'afcgb', 'dcgbe', 'ef', 'gaecbf', 'fecgb']
# ['4', 'daebgf', 'dfgcab', '8', '7', 'afcgb', 'dcgbe', '1', 'gaecbf', 'fecgb']
#
# ['cgafde', 'afbgdce', 'bgafc', 'gabcfd', 'bgdf', 'badgc', 'gf', 'aecdgb', 'ecabf', 'gfc']
# ['cgafde', '8', 'bgafc', 'gabcfd', '4', 'badgc', '1', 'aecdgb', 'ecabf', '7']
#
# ['fdgec', 'bgcad', 'bfec', 'gbefdc', 'dbf', 'gfdcea', 'fcbgaed', 'bf', 'bfgdea', 'gfdcb']
# ['fdgec', 'bgcad', '4', 'gbefdc', '7', 'gfdcea', '8', '1', 'bfgdea', 'gfdcb']
#
# ['dfceb', 'cdaf', 'bdfage', 'afebc', 'bgfdec', 'fa', 'gbcfdae', 'fea', 'gbeca', 'faecbd']
# ['dfceb', '4', 'bdfage', 'afebc', 'bgfdec', '1', '8', '7', 'gbeca', 'faecbd']
#
# ['fgcaeb', 'fcag', 'fa', 'bdace', 'efbcg', 'gdfbaec', 'fab', 'dfgbec', 'abfce', 'fabdge']
# ['fgcaeb', '4', '1', 'bdace', 'efbcg', '8', '7', 'dfgbec', 'abfce', 'fabdge']
#
# ['afegdc', 'fegdbc', 'gfeab', 'cdfb', 'dcegba', 'db', 'bde', 'degfc', 'bafcedg', 'dgfeb']
# ['afegdc', 'fegdbc', 'gfeab', '4', 'dcegba', '1', '7', 'degfc', '8', 'dgfeb']
#
# ['dg', 'gbd', 'adgfcb', 'cfeagb', 'bcfag', 'bcgfd', 'gdaf', 'cbfed', 'gcfaedb', 'ecabdg']
# ['1', '7', 'adgfcb', 'cfeagb', 'bcfag', 'bcgfd', '4', 'cbfed', '8', 'ecabdg']
#
# ['cebgfa', 'gcadfeb', 'afcdeb', 'dagfb', 'facdg', 'adbfge', 'bdf', 'db', 'egdb', 'ebfag']
# ['cebgfa', '8', 'afcdeb', 'dagfb', 'facdg', 'adbfge', '7', '1', '4', 'ebfag']
#
# ['adbf', 'fgd', 'bcegadf', 'cgfead', 'egbfd', 'bgeda', 'bdceag', 'bgfce', 'fd', 'aegbdf']
# ['4', '7', '8', 'cgfead', 'egbfd', 'bgeda', 'bdceag', 'bgfce', '1', 'aegbdf']
#
# ['ga', 'cgbfd', 'decba', 'gaecfb', 'dfbcga', 'cbdgfe', 'cbdegfa', 'fgad', 'agcbd', 'gab']
# ['1', 'cgbfd', 'decba', 'gaecfb', 'dfbcga', 'cbdgfe', '8', '4', 'agcbd', '7']
#
# ['egbfa', 'geca', 'fabcg', 'edfba', 'fge', 'fdcagb', 'cgebfa', 'dcefgb', 'bgdface', 'eg']
# ['egbfa', '4', 'fabcg', 'edfba', '7', 'fdcagb', 'cgebfa', 'dcefgb', '8', '1']
#
# ['egcad', 'fadbge', 'fbgd', 'faebg', 'acdbfe', 'edabg', 'bafcgde', 'dba', 'db', 'fecbag']
# ['egcad', 'fadbge', '4', 'faebg', 'acdbfe', 'edabg', '8', '7', '1', 'fecbag']
#
# ['ad', 'dcbag', 'cegdabf', 'cgbea', 'feacgd', 'adeb', 'debcga', 'acd', 'agbcef', 'dfbcg']
# ['1', 'dcbag', '8', 'cgbea', 'feacgd', '4', 'debcga', '7', 'agbcef', 'dfbcg']
#
# ['cebad', 'cfadgbe', 'ecd', 'gdcbae', 'cage', 'cgdbef', 'ce', 'cgdba', 'gcafdb', 'adebf']
# ['cebad', '8', '7', 'gdcbae', '4', 'cgdbef', '1', 'cgdba', 'gcafdb', 'adebf']
#
# ['fagceb', 'cbdef', 'cabgfd', 'gadbc', 'ae', 'dfcgeba', 'gcebad', 'bae', 'aegd', 'abdce']
# ['fagceb', 'cbdef', 'cabgfd', 'gadbc', '1', '8', 'gcebad', '7', '4', 'abdce']
#
# ['efgcab', 'eagdf', 'de', 'ead', 'bfde', 'cdgabfe', 'ebfdag', 'fbeag', 'agedbc', 'gfdac']
# ['efgcab', 'eagdf', '1', '7', '4', '8', 'ebfdag', 'fbeag', 'agedbc', 'gfdac']
#
# ['gfbeadc', 'cgeafb', 'gdecf', 'bcedgf', 'dfgca', 'cdagef', 'bgafd', 'afc', 'ca', 'cdae']
# ['8', 'cgeafb', 'gdecf', 'bcedgf', 'dfgca', 'cdagef', 'bgafd', '7', '1', '4']
#
# ['fc', 'egfbcda', 'dfc', 'degfca', 'fgdbc', 'dafbg', 'febc', 'dcebg', 'cebgfd', 'ecbagd']
# ['1', '8', '7', 'degfca', 'fgdbc', 'dafbg', '4', 'dcebg', 'cebgfd', 'ecbagd']
#
# ['db', 'acegb', 'fdbegac', 'dgefa', 'gfcdeb', 'egadbc', 'cdba', 'bde', 'geabd', 'becfag']
# ['1', 'acegb', '8', 'dgefa', 'gfcdeb', 'egadbc', '4', '7', 'geabd', 'becfag']
#
# ['ecg', 'acfgde', 'cedb', 'dfecbg', 'gcfdba', 'ec', 'cdbgf', 'cfebg', 'efdbcag', 'fegba']
# ['7', 'acfgde', '4', 'dfecbg', 'gcfdba', '1', 'cdbgf', 'cfebg', '8', 'fegba']
#
# ['fgcadeb', 'ecfagd', 'egfda', 'cd', 'cdf', 'edac', 'fecdg', 'fagdeb', 'gfdbca', 'gcefb']
# ['8', 'ecfagd', 'egfda', '1', '7', '4', 'fecdg', 'fagdeb', 'gfdbca', 'gcefb']
#
# ['cfgedb', 'fgdba', 'cgdef', 'edgfa', 'ea', 'fbaegc', 'age', 'decgaf', 'aced', 'gbedafc']
# ['cfgedb', 'fgdba', 'cgdef', 'edgfa', '1', 'fbaegc', '7', 'decgaf', '4', '8']
#
# ['de', 'agebc', 'bcdgf', 'fagbec', 'adbegc', 'cbged', 'daec', 'gdefacb', 'deb', 'gdfeba']
# ['1', 'agebc', 'bcdgf', 'fagbec', 'adbegc', 'cbged', '4', '8', '7', 'gdfeba']
#
# ['fdeg', 'cfbgda', 'dcaef', 'dceab', 'gdefac', 'dcf', 'cgafe', 'begdcfa', 'cfeabg', 'df']
# ['4', 'cfbgda', 'dcaef', 'dceab', 'gdefac', '7', 'cgafe', '8', 'cfeabg', '1']
#
# ['efgbd', 'cgfbe', 'gcb', 'egabcdf', 'debfag', 'cg', 'cgdbfa', 'bceaf', 'cdge', 'degfcb']
# ['efgbd', 'cgfbe', '7', '8', 'debfag', '1', 'cgdbfa', 'bceaf', '4', 'degfcb']
#
# ['aefbd', 'bfaec', 'bdgcaf', 'dgeb', 'de', 'fgceabd', 'fgaedc', 'egbdfa', 'badgf', 'fed']
# ['aefbd', 'bfaec', 'bdgcaf', '4', '1', '8', 'fgaedc', 'egbdfa', 'badgf', '7']
#
# ['bcdea', 'defagbc', 'fdce', 'cbfade', 'fagbd', 'egcfab', 'cf', 'adgebc', 'cbf', 'dfbca']
# ['bcdea', '8', '4', 'cbfade', 'fagbd', 'egcfab', '1', 'adgebc', '7', 'dfbca']
#
# ['abdc', 'cb', 'bgc', 'bacfeg', 'fabgd', 'cfdeg', 'fcdbg', 'gcdebfa', 'dgaebf', 'dgbfac']
# ['4', '1', '7', 'bacfeg', 'fabgd', 'cfdeg', 'fcdbg', '8', 'dgaebf', 'dgbfac']
#
# ['bfgca', 'gfbadce', 'dbcag', 'ecabf', 'cfgead', 'fcg', 'gf', 'edabcf', 'fbge', 'afgbce']
# ['bfgca', '8', 'dbcag', 'ecabf', 'cfgead', '7', '1', 'edabcf', '4', 'afgbce']
#
# ['afgbde', 'cfdgb', 'afbcge', 'gbfec', 'ec', 'cfe', 'dgface', 'gfbae', 'fcagbed', 'beca']
# ['afgbde', 'cfdgb', 'afbcge', 'gbfec', '1', '7', 'dgface', 'gfbae', '8', '4']
#
# ['bfdga', 'gaed', 'dbagfe', 'cgdbef', 'edfba', 'bcaef', 'de', 'gbeadcf', 'gdfacb', 'bed']
# ['bfdga', '4', 'dbagfe', 'cgdbef', 'edfba', 'bcaef', '1', '8', 'gdfacb', '7']
#
# ['adcb', 'ecgafd', 'ba', 'abf', 'bfedca', 'gdbfae', 'edcaf', 'bgaefdc', 'fcbeg', 'fbeca']
# ['4', 'ecgafd', '1', '7', 'bfedca', 'gdbfae', 'edcaf', '8', 'fcbeg', 'fbeca']
#
# ['ac', 'bdecf', 'bac', 'daegb', 'bdegca', 'bcefga', 'gacd', 'febdgac', 'abdgef', 'badec']
# ['1', 'bdecf', '7', 'daegb', 'bdegca', 'bcefga', '4', '8', 'abdgef', 'badec']
#
# ['gcd', 'ebcd', 'cgfbade', 'dabgfc', 'gbdcfe', 'fdcge', 'gceabf', 'dc', 'gfead', 'ebfcg']
# ['7', '4', '8', 'dabgfc', 'gbdcfe', 'fdcge', 'gceabf', '1', 'gfead', 'ebfcg']
#
# ['ceg', 'cfgae', 'facbde', 'ge', 'gcfba', 'bcdfega', 'edacf', 'fcgedb', 'dage', 'cdegfa']
# ['7', 'cfgae', 'facbde', '1', 'gcfba', '8', 'edacf', 'fcgedb', '4', 'cdegfa']
#
# ['decgf', 'fadeg', 'fgaced', 'febda', 'eag', 'fagc', 'ag', 'bgadec', 'fegbdc', 'bafecdg']
# ['decgf', 'fadeg', 'fgaced', 'febda', '7', '4', '1', 'bgadec', 'fegbdc', '8']
#
# ['da', 'bdeca', 'fdgbce', 'afdbegc', 'efbac', 'gacedb', 'fbdcga', 'acd', 'cdegb', 'gdea']
# ['1', 'bdeca', 'fdgbce', '8', 'efbac', 'gacedb', 'fbdcga', '7', 'cdegb', '4']
#
# ['ebagdc', 'cdaefg', 'cebfg', 'fadg', 'gd', 'ecgfd', 'dge', 'afedc', 'ebadcf', 'dfbcage']
# ['ebagdc', 'cdaefg', 'cebfg', '4', '1', 'ecgfd', '7', 'afedc', 'ebadcf', '8']
#
# ['fdbcea', 'ag', 'fag', 'fegdba', 'ecagfd', 'bdgcf', 'afecd', 'afgdc', 'cgae', 'efgabdc']
# ['fdbcea', '1', '7', 'fegdba', 'ecagfd', 'bdgcf', 'afecd', 'afgdc', '4', '8']
#
# ['ea', 'cabgde', 'acbgfe', 'cefbgda', 'acde', 'edbcg', 'aeb', 'ebfgcd', 'dfgab', 'aebgd']
# ['1', 'cabgde', 'acbgfe', '8', '4', 'edbcg', '7', 'ebfgcd', 'dfgab', 'aebgd']
#
# ['acfd', 'ebgfcad', 'fecbgd', 'dcgabe', 'ca', 'eagfc', 'eac', 'gefab', 'gfdce', 'cgfdae']
# ['4', '8', 'fecbgd', 'dcgabe', '1', 'eagfc', '7', 'gefab', 'gfdce', 'cgfdae']
#
# ['fdecab', 'bf', 'fdcb', 'egdaf', 'cgadefb', 'edacgb', 'ceadb', 'daebf', 'afegbc', 'efb']
# ['fdecab', '1', '4', 'egdaf', '8', 'edacgb', 'ceadb', 'daebf', 'afegbc', '7']
#
# ['badef', 'fbedag', 'daebcgf', 'bgcfa', 'dacgef', 'cfadeb', 'dac', 'dcbaf', 'dcbe', 'cd']
# ['badef', 'fbedag', '8', 'bgcfa', 'dacgef', 'cfadeb', '7', 'dcbaf', '4', '1']
#
# ['fagedb', 'acbge', 'fceabg', 'cegfb', 'bagcde', 'aecf', 'cfbgd', 'aegdcbf', 'efb', 'fe']
# ['fagedb', 'acbge', 'fceabg', 'cegfb', 'bagcde', '4', 'cfbgd', '8', '7', '1']
#
# ['efagd', 'dfacg', 'fgcb', 'dgc', 'cefbad', 'cgabde', 'cadfgb', 'dbafecg', 'cdbaf', 'gc']
# ['efagd', 'dfacg', '4', '7', 'cefbad', 'cgabde', 'cadfgb', '8', 'cdbaf', '1']
#
# ['egcbf', 'gbdafe', 'fd', 'edf', 'gfecd', 'gcbdae', 'aecdg', 'fgdcea', 'gacdbef', 'cfad']
# ['egcbf', 'gbdafe', '1', '7', 'gfecd', 'gcbdae', 'aecdg', 'fgdcea', '8', '4']
#
# ['bdfceg', 'acd', 'dfbce', 'bfdag', 'ac', 'adcfb', 'daefcb', 'egadcf', 'cbae', 'edfabcg']
# ['bdfceg', '7', 'dfbce', 'bfdag', '1', 'adcfb', 'daefcb', 'egadcf', '4', '8']
#
# ['bcf', 'badcf', 'ecdaf', 'eadgbcf', 'abgf', 'defcbg', 'bf', 'ebgcda', 'bcgda', 'acbfdg']
# ['7', 'badcf', 'ecdaf', '8', '4', 'defcbg', '1', 'ebgcda', 'bcgda', 'acbfdg']
#
# ['da', 'cda', 'adceg', 'bead', 'abgcfed', 'ceagdb', 'gcbed', 'cfgae', 'agdbfc', 'dfbegc']
# ['1', '7', 'adceg', '4', '8', 'ceagdb', 'gcbed', 'cfgae', 'agdbfc', 'dfbegc']
#
# ['gbaecf', 'debfg', 'dbaceg', 'badc', 'eagdb', 'ab', 'abfegdc', 'dcgea', 'cdefag', 'bga']
# ['gbaecf', 'debfg', 'dbaceg', '4', 'eagdb', '1', '8', 'dcgea', 'cdefag', '7']
#
# ['dacfbge', 'dafbc', 'baegdc', 'fagbde', 'dacgb', 'fbcg', 'bdfcga', 'fb', 'abf', 'fdace']
# ['8', 'dafbc', 'baegdc', 'fagbde', 'dacgb', '4', 'bdfcga', '1', '7', 'fdace']
#
# ['acbgf', 'gadefb', 'cd', 'egcfad', 'bedc', 'cad', 'cadbg', 'cagbdfe', 'gdeba', 'bdgaec']
# ['acbgf', 'gadefb', '1', 'egcfad', '4', '7', 'cadbg', '8', 'gdeba', 'bdgaec']
#
# ['fdbgcae', 'feacgd', 'gcdfe', 'cgdefb', 'gabfe', 'defgb', 'dgb', 'db', 'caegdb', 'dfcb']
# ['8', 'feacgd', 'gcdfe', 'cgdefb', 'gabfe', 'defgb', '7', '1', 'caegdb', '4']
#
# ['ae', 'gacbe', 'facbge', 'cbdefa', 'eca', 'acfdbg', 'afbgc', 'gecbd', 'gcaebfd', 'agfe']
# ['1', 'gacbe', 'facbge', 'cbdefa', '7', 'acfdbg', 'afbgc', 'gecbd', '8', '4']
#
# ['bfdceg', 'badecfg', 'bgefda', 'ba', 'bfa', 'cbda', 'fcage', 'cdeabf', 'fbaec', 'efbdc']
# ['bfdceg', '8', 'bgefda', '1', '7', '4', 'fcage', 'cdeabf', 'fbaec', 'efbdc']
#
# ['gbc', 'bdgce', 'gcbdefa', 'geac', 'cg', 'bedca', 'dfbcea', 'dgcabe', 'afdcgb', 'gedbf']
# ['7', 'bdgce', '8', '4', '1', 'bedca', 'dfbcea', 'dgcabe', 'afdcgb', 'gedbf']
#
# ['becdf', 'gaedcb', 'cgedaf', 'aegcf', 'fagcdeb', 'gfab', 'gefabc', 'cebfa', 'bca', 'ab']
# ['becdf', 'gaedcb', 'cgedaf', 'aegcf', '8', '4', 'gefabc', 'cebfa', '7', '1']
#
# ['eagbc', 'acfdge', 'db', 'gfadc', 'fdgb', 'fbagcd', 'dba', 'dcagb', 'gecfbad', 'efbdac']
# ['eagbc', 'acfdge', '1', 'gfadc', '4', 'fbagcd', '7', 'dcagb', '8', 'efbdac']
#
# ['ga', 'eafg', 'adbge', 'gabdecf', 'cbade', 'bdgfea', 'afgbcd', 'gfbde', 'gab', 'cgedfb']
# ['1', '4', 'adbge', '8', 'cbade', 'bdgfea', 'afgbcd', 'gfbde', '7', 'cgedfb']
#
# ['efabc', 'cdeaf', 'dgcfa', 'ecbafg', 'ed', 'dagfbe', 'bfadec', 'egdbfac', 'cedb', 'efd']
# ['efabc', 'cdeaf', 'dgcfa', 'ecbafg', '1', 'dagfbe', 'bfadec', '8', '4', '7']
#
# ['bagf', 'fb', 'cfeba', 'gcbade', 'cgaeb', 'adfce', 'befgcd', 'cfb', 'defabcg', 'gcfaeb']
# ['4', '1', 'cfeba', 'gcbade', 'cgaeb', 'adfce', 'befgcd', '7', '8', 'gcfaeb']
#
# ['dfceg', 'gfcedb', 'bdfea', 'gb', 'bfedg', 'cgdb', 'afgebcd', 'fgdace', 'cbfgea', 'fbg']
# ['dfceg', 'gfcedb', 'bdfea', '1', 'bfedg', '4', '8', 'fgdace', 'cbfgea', '7']
#
# ['gecfab', 'dacgf', 'cfbgdae', 'afdcbg', 'afde', 'cea', 'gcebd', 'fgecad', 'gcdae', 'ea']
# ['gecfab', 'dacgf', '8', 'afdcbg', '4', '7', 'gcebd', 'fgecad', 'gcdae', '1']
#
# ['ag', 'afg', 'bgcdef', 'abfec', 'begdf', 'gadfbce', 'bfgae', 'egbafd', 'egda', 'gadcbf']
# ['1', '7', 'bgcdef', 'abfec', 'begdf', '8', 'bfgae', 'egbafd', '4', 'gadcbf']
#
# ['cgadf', 'cegdbf', 'egaf', 'dga', 'efcadbg', 'dfcge', 'ag', 'cabdf', 'eagfcd', 'cegdba']
# ['cgadf', 'cegdbf', '4', '7', '8', 'dfcge', '1', 'cabdf', 'eagfcd', 'cegdba']
#
# ['dcbge', 'fdgabc', 'cegba', 'aegfc', 'gfebdc', 'ecfdbga', 'aedb', 'cgebad', 'ab', 'bga']
# ['dcbge', 'fdgabc', 'cegba', 'aegfc', 'gfebdc', '8', '4', 'cgebad', '1', '7']
#
# ['cdg', 'fgdb', 'adfecb', 'gdabfc', 'cagfd', 'fbadc', 'febcdag', 'cdebga', 'geafc', 'dg']
# ['7', '4', 'adfecb', 'gdabfc', 'cagfd', 'fbadc', '8', 'cdebga', 'geafc', '1']
#
# ['debgac', 'fceadb', 'eg', 'gbcfeda', 'gfabde', 'efgd', 'gfbac', 'feadb', 'gbe', 'baegf']
# ['debgac', 'fceadb', '1', '8', 'gfabde', '4', 'gfbac', 'feadb', '7', 'baegf']
#
# ['cf', 'bgcfe', 'cfg', 'cdgabe', 'cbdf', 'dcfegba', 'bgafe', 'cdefga', 'gbecd', 'edbgcf']
# ['1', 'bgcfe', '7', 'cdgabe', '4', '8', 'bgafe', 'cdefga', 'gbecd', 'edbgcf']
#
# ['cbefag', 'gbe', 'agec', 'cbgfdea', 'gdbfa', 'facbed', 'dcebgf', 'eg', 'eafbc', 'ebafg']
# ['cbefag', '7', '4', '8', 'gdbfa', 'facbed', 'dcebgf', '1', 'eafbc', 'ebafg']
#
# ['gfd', 'bfgec', 'dfeagbc', 'fedgbc', 'fd', 'cdbf', 'fbeagc', 'efbdg', 'ecgadf', 'daegb']
# ['7', 'bfgec', '8', 'fedgbc', '1', '4', 'fbeagc', 'efbdg', 'ecgadf', 'daegb']
#
# ['fcedbg', 'bcde', 'be', 'fgbecda', 'bfe', 'fadecg', 'edgbaf', 'gcdef', 'becfg', 'fbagc']
# ['fcedbg', '4', '1', '8', '7', 'fadecg', 'edgbaf', 'gcdef', 'becfg', 'fbagc']
#
# ['fbdgae', 'gefabdc', 'bfgdca', 'gbf', 'fcabed', 'cafbg', 'bcdaf', 'gcbd', 'gb', 'agfec']
# ['fbdgae', '8', 'bfgdca', '7', 'fcabed', 'cafbg', 'bcdaf', '4', '1', 'agfec']
#
# ['cfbegad', 'gdfcb', 'bfgde', 'bcdegf', 'egcb', 'bc', 'adcfg', 'gadbfe', 'beafdc', 'cbd']
# ['8', 'gdfcb', 'bfgde', 'bcdegf', '4', '1', 'adcfg', 'gadbfe', 'beafdc', '7']
#
# ['abgcf', 'ecabdgf', 'dba', 'acgdfb', 'gfebd', 'dfac', 'adbgec', 'da', 'afgdb', 'cbaefg']
# ['abgcf', '8', '7', 'acgdfb', 'gfebd', '4', 'adbgec', '1', 'afgdb', 'cbaefg']
#
# ['bdecfag', 'ef', 'bcefda', 'adgce', 'feagbc', 'gbef', 'gfcae', 'fcgab', 'afe', 'fdabcg']
# ['8', '1', 'bcefda', 'adgce', 'feagbc', '4', 'gfcae', 'fcgab', '7', 'fdabcg']
#
# ['dg', 'cbgeda', 'bgdfa', 'egfd', 'dgb', 'gebadfc', 'febcda', 'gcbaf', 'deabf', 'gaebdf']
# ['1', 'cbgeda', 'bgdfa', '4', '7', '8', 'febcda', 'gcbaf', 'deabf', 'gaebdf']
#
# ['cfagedb', 'eacgd', 'baecfd', 'cbafd', 'ef', 'eaf', 'bdfe', 'fgbcad', 'dface', 'febacg']
# ['8', 'eacgd', 'baecfd', 'cbafd', '1', '7', '4', 'fgbcad', 'dface', 'febacg']
#
# ['fdageb', 'egbcf', 'ec', 'ceb', 'dgcbf', 'gfeba', 'fegcab', 'acef', 'bgaecd', 'cebadgf']
# ['fdageb', 'egbcf', '1', '7', 'dgcbf', 'gfeba', 'fegcab', '4', 'bgaecd', '8']
#
# ['agecbfd', 'fcd', 'gbedac', 'dbcfag', 'dfacg', 'df', 'gbcda', 'fcaeg', 'febacd', 'dfgb']
# ['8', '7', 'gbedac', 'dbcfag', 'dfacg', '1', 'gbcda', 'fcaeg', 'febacd', '4']
#
# ['dafebc', 'gbfa', 'agdfc', 'fbcgad', 'fgceadb', 'cdbfg', 'bf', 'bfd', 'adgfec', 'bdcge']
# ['dafebc', '4', 'agdfc', 'fbcgad', '8', 'cdbfg', '1', '7', 'adgfec', 'bdcge']
#
# ['caebgd', 'bgcf', 'gabef', 'bf', 'agbec', 'abfcged', 'bgeacf', 'ebf', 'edfag', 'cfdeba']
# ['caebgd', '4', 'gabef', '1', 'agbec', '8', 'bgeacf', '7', 'edfag', 'cfdeba']
#
# ['deba', 'eb', 'bfe', 'bfaedc', 'ebfdc', 'cgdfae', 'gdcafbe', 'cbeagf', 'bgdcf', 'dacfe']
# ['4', '1', '7', 'bfaedc', 'ebfdc', 'cgdfae', '8', 'cbeagf', 'bgdcf', 'dacfe']
#
# ['aefcbgd', 'afcde', 'cea', 'aefcgd', 'dgefba', 'efagd', 'ca', 'cagf', 'gcdabe', 'edcfb']
# ['8', 'afcde', '7', 'aefcgd', 'dgefba', 'efagd', '1', '4', 'gcdabe', 'edcfb']
#
# ['cadge', 'fbagec', 'ag', 'ebcdgfa', 'dagf', 'afedc', 'age', 'ecdabf', 'cbdeg', 'gcfdea']
# ['cadge', 'fbagec', '1', '8', '4', 'afedc', '7', 'ecdabf', 'cbdeg', 'gcfdea']
#
# ['cbgefda', 'acd', 'afgdeb', 'dc', 'fdgab', 'dcbfae', 'gdbc', 'cdbgaf', 'acfeg', 'adcfg']
# ['8', '7', 'afgdeb', '1', 'fdgab', 'dcbfae', '4', 'cdbgaf', 'acfeg', 'adcfg']
#
# ['cegad', 'bfgcd', 'baegfc', 'facgd', 'aebgdc', 'af', 'fag', 'feda', 'edafcg', 'cgfbdae']
# ['cegad', 'bfgcd', 'baegfc', 'facgd', 'aebgdc', '1', '7', '4', 'edafcg', '8']
#
# ['aecgdf', 'ecgfb', 'bfdea', 'cfbaged', 'dgbfce', 'cdf', 'gdcb', 'dc', 'bcdfe', 'aegfbc']
# ['aecgdf', 'ecgfb', 'bfdea', '8', 'dgbfce', '7', '4', '1', 'bcdfe', 'aegfbc']
#
# ['bcafe', 'bfcdea', 'febga', 'ac', 'cfa', 'cdeagf', 'dabc', 'cfdaegb', 'cfedb', 'cfgebd']
# ['bcafe', 'bfcdea', 'febga', '1', '7', 'cdeagf', '4', '8', 'cfedb', 'cfgebd']
#
# ['cgfedb', 'afcb', 'fdc', 'fc', 'bdgcea', 'gacdb', 'gedaf', 'ceafbgd', 'cfgda', 'adcgbf']
# ['cgfedb', '4', '7', '1', 'bdgcea', 'gacdb', 'gedaf', '8', 'cfgda', 'adcgbf']
#
# ['ebcf', 'def', 'cgaedbf', 'becad', 'bagfd', 'egdcab', 'fgaecd', 'ecfdba', 'ef', 'dfbae']
# ['4', '7', '8', 'becad', 'bagfd', 'egdcab', 'fgaecd', 'ecfdba', '1', 'dfbae']
#
# ['gcfabe', 'gcabe', 'dfgca', 'beagdf', 'fbg', 'abfgc', 'bfce', 'bedcag', 'fb', 'fbcagde']
# ['gcfabe', 'gcabe', 'dfgca', 'beagdf', '7', 'abfgc', '4', 'bedcag', '1', '8']
#
# ['dca', 'ebfdacg', 'cgbd', 'gabfde', 'cgfad', 'gadbcf', 'cfeabd', 'fgeac', 'bgdaf', 'cd']
# ['7', '8', '4', 'gabfde', 'cgfad', 'gadbcf', 'cfeabd', 'fgeac', 'bgdaf', '1']
#
# ['ebfgadc', 'efgbad', 'bdfceg', 'cbdfg', 'gecb', 'bfedc', 'fgb', 'gb', 'dafcg', 'fedbac']
# ['8', 'efgbad', 'bdfceg', 'cbdfg', '4', 'bfedc', '7', '1', 'dafcg', 'fedbac']
#
# ['ecadfb', 'fdgceba', 'gdebac', 'dea', 'fegdc', 'feagcb', 'ebafc', 'fadce', 'da', 'fabd']
# ['ecadfb', '8', 'gdebac', '7', 'fegdc', 'feagcb', 'ebafc', 'fadce', '1', '4']
#
# ['dbf', 'fdaceb', 'cdgefa', 'bf', 'febgacd', 'aefb', 'fdbca', 'cdefbg', 'dcagb', 'edcaf']
# ['7', 'fdaceb', 'cdgefa', '1', '8', '4', 'fdbca', 'cdefbg', 'dcagb', 'edcaf']
#
# ['gdbef', 'bae', 'edbfcg', 'bfcag', 'agde', 'gebaf', 'gaebfdc', 'cfdabe', 'afdebg', 'ae']
# ['gdbef', '7', 'edbfcg', 'bfcag', '4', 'gebaf', '8', 'cfdabe', 'afdebg', '1']
#
# ['edabf', 'dgbcf', 'bce', 'afecgb', 'degc', 'dbfec', 'bfgcaed', 'ce', 'bgdcef', 'cdfbag']
# ['edabf', 'dgbcf', '7', 'afecgb', '4', 'dbfec', '8', '1', 'bgdcef', 'cdfbag']
#
# ['bdcfga', 'fag', 'dgafc', 'fg', 'dacbf', 'bdafec', 'cfbg', 'fabdgec', 'eabdfg', 'eagcd']
# ['bdcfga', '7', 'dgafc', '1', 'dacbf', 'bdafec', '4', '8', 'eabdfg', 'eagcd']
#
# ['cgfda', 'badfc', 'ba', 'gcfdba', 'acfbdeg', 'bcga', 'ebfdag', 'faegcd', 'abd', 'dcfbe']
# ['cgfda', 'badfc', '1', 'gcfdba', '8', '4', 'ebfdag', 'faegcd', '7', 'dcfbe']
#
# ['bcdae', 'febgc', 'egdbafc', 'fd', 'gcfd', 'bdefc', 'bcedgf', 'fbdega', 'fde', 'fabegc']
# ['bcdae', 'febgc', '8', '1', '4', 'bdefc', 'bcedgf', 'fbdega', '7', 'fabegc']
#
# ['bfedacg', 'agfdec', 'deg', 'gd', 'decbf', 'ebgcd', 'eadgbc', 'gbfeca', 'bceag', 'gbad']
# ['8', 'agfdec', '7', '1', 'decbf', 'ebgcd', 'eadgbc', 'gbfeca', 'bceag', '4']
#
# ['acbgd', 'dbfceg', 'cegfdab', 'dbaegc', 'aebcg', 'ecb', 'be', 'dcbgaf', 'egcfa', 'eabd']
# ['acbgd', 'dbfceg', '8', 'dbaegc', 'aebcg', '7', '1', 'dcbgaf', 'egcfa', '4']
#
# ['gda', 'debfa', 'gdfe', 'gd', 'cfdgbae', 'bdagec', 'badgfe', 'bgdaf', 'cbdefa', 'fcabg']
# ['7', 'debfa', '4', '1', '8', 'bdagec', 'badgfe', 'bgdaf', 'cbdefa', 'fcabg']
#
# ['febgcd', 'cdaegf', 'bf', 'fabge', 'edafbgc', 'gfaedb', 'baegc', 'ebf', 'fdage', 'fabd']
# ['febgcd', 'cdaegf', '1', 'fabge', '8', 'gfaedb', 'baegc', '7', 'fdage', '4']
#
# ['adegfb', 'cbgefda', 'dcag', 'agbfdc', 'gbcfa', 'gadfb', 'bfecg', 'ac', 'acdfbe', 'cba']
# ['adegfb', '8', '4', 'agbfdc', 'gbcfa', 'gadfb', 'bfecg', '1', 'acdfbe', '7']
#
# ['adcf', 'fbecdga', 'dbeagf', 'ac', 'eca', 'gefdac', 'edcag', 'cfbeag', 'edgaf', 'cgebd']
# ['4', '8', 'dbeagf', '1', '7', 'gefdac', 'edcag', 'cfbeag', 'edgaf', 'cgebd']
#
# ['acbdgf', 'gaecfb', 'ad', 'cbdfaeg', 'gebfa', 'gcbed', 'efda', 'gad', 'baegd', 'afedbg']
# ['acbdgf', 'gaecfb', '1', '8', 'gebfa', 'gcbed', '4', '7', 'baegd', 'afedbg']
#
# ['da', 'abd', 'dbgfc', 'dgca', 'gadbf', 'bcgedaf', 'dfbacg', 'fbeadc', 'bfecdg', 'gabef']
# ['1', '7', 'dbgfc', '4', 'gadbf', '8', 'dfbacg', 'fbeadc', 'bfecdg', 'gabef']
#
# ['agcdf', 'cbfgd', 'da', 'dacb', 'cagfe', 'abgdfc', 'aedfbg', 'agd', 'edcbgfa', 'fegcdb']
# ['agcdf', 'cbfgd', '1', '4', 'cagfe', 'abgdfc', 'aedfbg', '7', '8', 'fegcdb']
#
# ['cd', 'aegdb', 'acfbe', 'bgdc', 'ebacd', 'dbfgea', 'feacdgb', 'agfdce', 'dce', 'dbceag']
# ['1', 'aegdb', 'acfbe', '4', 'ebacd', 'dbfgea', '8', 'agfdce', '7', 'dbceag']
#
# ['abc', 'deacbg', 'aecf', 'cgafb', 'dcbgf', 'cgfbae', 'gbaef', 'ca', 'geabdf', 'gcbafde']
# ['7', 'deacbg', '4', 'cgafb', 'dcbgf', 'cgfbae', 'gbaef', '1', 'geabdf', '8']
#
# ['eagcb', 'edacgfb', 'abfegd', 'abedf', 'aefdcb', 'gfda', 'dcbfge', 'gbafe', 'fg', 'gfb']
# ['eagcb', '8', 'abfegd', 'abedf', 'aefdcb', '4', 'dcbfge', 'gbafe', '1', '7']
#
# ['dgcab', 'aedgb', 'gbdcfae', 'acbe', 'beg', 'gebfdc', 'gdbcfa', 'fdage', 'dceabg', 'be']
# ['dgcab', 'aedgb', '8', '4', '7', 'gebfdc', 'gdbcfa', 'fdage', 'dceabg', '1']
#
# ['gd', 'dfcgea', 'afdgeb', 'cdfae', 'befacd', 'beagc', 'ged', 'daegc', 'afebdcg', 'cdfg']
# ['1', 'dfcgea', 'afdgeb', 'cdfae', 'befacd', 'beagc', '7', 'daegc', '8', '4']
#
# ['gfcebad', 'gfeca', 'bdcae', 'fbeg', 'cbgafd', 'bg', 'dcagef', 'gab', 'gacbe', 'fabgce']
# ['8', 'gfeca', 'bdcae', '4', 'cbgafd', '1', 'dcagef', '7', 'gacbe', 'fabgce']
#
# ['fegdc', 'bdag', 'gbedac', 'dcfeba', 'gfeabc', 'ebfgdac', 'gedac', 'ga', 'ceadb', 'cag']
# ['fegdc', '4', 'gbedac', 'dcfeba', 'gfeabc', '8', 'gedac', '1', 'ceadb', '7']
#
# ['deabcf', 'dcfa', 'cd', 'ebgfda', 'ecabg', 'aecbd', 'cegfbad', 'dbc', 'cgfedb', 'faebd']
# ['deabcf', '4', '1', 'ebgfda', 'ecabg', 'aecbd', '8', '7', 'cgfedb', 'faebd']
#
# ['gedcab', 'bagdfe', 'bf', 'aecdf', 'begf', 'aefbd', 'dbf', 'eabdgcf', 'bfdagc', 'eagdb']
# ['gedcab', 'bagdfe', '1', 'aecdf', '4', 'aefbd', '7', '8', 'bfdagc', 'eagdb']
#
# ['cgfd', 'afecg', 'cedgfa', 'eabcd', 'aefgcb', 'afdgceb', 'dfa', 'fd', 'eafcd', 'debfga']
# ['4', 'afecg', 'cedgfa', 'eabcd', 'aefgcb', '8', '7', '1', 'eafcd', 'debfga']
#
# ['cdagbe', 'agefb', 'fedabc', 'fagcb', 'gfebdac', 'fgde', 'baegd', 'fe', 'eadbfg', 'feb']
# ['cdagbe', 'agefb', 'fedabc', 'fagcb', '8', '4', 'baegd', '1', 'eadbfg', '7']
#
# ['adcfb', 'bdcga', 'df', 'daf', 'gdabfe', 'cafdbe', 'cbgfae', 'decf', 'becfa', 'cbgadfe']
# ['adcfb', 'bdcga', '1', '7', 'gdabfe', 'cafdbe', 'cbgfae', '4', 'becfa', '8']
#
# ['dcgef', 'agc', 'cfbadg', 'ga', 'afgec', 'bcaefd', 'efcba', 'abeg', 'cdeagbf', 'aecbfg']
# ['dcgef', '7', 'cfbadg', '1', 'afgec', 'bcaefd', 'efcba', '4', '8', 'aecbfg']
#
# ['adcge', 'gdcbaf', 'bad', 'cgdeaf', 'bced', 'abfge', 'dgaeb', 'db', 'aedbgc', 'ebdafgc']
# ['adcge', 'gdcbaf', '7', 'cgdeaf', '4', 'abfge', 'dgaeb', '1', 'aedbgc', '8']
#
# ['bgd', 'adfcge', 'gdacb', 'fadb', 'bd', 'degfabc', 'bcaeg', 'dcfag', 'gefdbc', 'gbdafc']
# ['7', 'adfcge', 'gdacb', '4', '1', '8', 'bcaeg', 'dcfag', 'gefdbc', 'gbdafc']
#
# ['bdf', 'cbadef', 'ecafd', 'bfacdg', 'bd', 'cbde', 'baefd', 'afcdeg', 'ebgaf', 'edagcbf']
# ['7', 'cbadef', 'ecafd', 'bfacdg', '1', '4', 'baefd', 'afcdeg', 'ebgaf', '8']
#
# ['cbdaf', 'efbd', 'ef', 'afbec', 'caefgd', 'dagbecf', 'gcadbf', 'cbgea', 'dbeacf', 'aef']
# ['cbdaf', '4', '1', 'afbec', 'caefgd', '8', 'gcadbf', 'cbgea', 'dbeacf', '7']
#
# ['gbfec', 'ed', 'fgebdc', 'defacgb', 'deb', 'gedc', 'cfebd', 'fedbga', 'cabdf', 'abcefg']
# ['gbfec', '1', 'fgebdc', '8', '7', '4', 'cfebd', 'fedbga', 'cabdf', 'abcefg']
#
# ['dgc', 'aedcg', 'aedcf', 'gd', 'acegdfb', 'cageb', 'edgb', 'dgcafb', 'cbegfa', 'ceabdg']
# ['7', 'aedcg', 'aedcf', '1', '8', 'cageb', '4', 'dgcafb', 'cbegfa', 'ceabdg']
#
# ['abf', 'gdbaef', 'abgfc', 'bf', 'gcafe', 'bdagc', 'dbcagf', 'cadbge', 'bdfcgae', 'fbdc']
# ['7', 'gdbaef', 'abgfc', '1', 'gcafe', 'bdagc', 'dbcagf', 'cadbge', '8', '4']
#
# ['becfdga', 'eac', 'acedf', 'cgbeda', 'gafdec', 'fabcd', 'egfda', 'ecfg', 'dgaefb', 'ce']
# ['8', '7', 'acedf', 'cgbeda', 'gafdec', 'fabcd', 'egfda', '4', 'dgaefb', '1']
#
# ['bdgceaf', 'febg', 'bfacdg', 'feacb', 'gaebfc', 'aebdc', 'ef', 'cfbga', 'facegd', 'fec']
# ['8', '4', 'bfacdg', 'feacb', 'gaebfc', 'aebdc', '1', 'cfbga', 'facegd', '7']
#
# ['baf', 'geacf', 'ab', 'cfdebga', 'cfbgde', 'fgcbd', 'gfbdea', 'dbac', 'gcfab', 'adbcfg']
# ['7', 'geacf', '1', '8', 'cfbgde', 'fgcbd', 'gfbdea', '4', 'gcfab', 'adbcfg']
#
# ['cd', 'ebgcf', 'ebdc', 'dagbf', 'fbgced', 'fgecab', 'cgd', 'fedagc', 'fbcgd', 'fgecbad']
# ['1', 'ebgcf', '4', 'dagbf', 'fbgced', 'fgecab', '7', 'fedagc', 'fbcgd', '8']
#
# ['dfbcag', 'geafc', 'agdec', 'da', 'gad', 'dgecb', 'cgbfae', 'faed', 'edafgc', 'adcgfeb']
# ['dfbcag', 'geafc', 'agdec', '1', '7', 'dgecb', 'cgbfae', '4', 'edafgc', '8']
#
# ['dfegac', 'aegbf', 'cg', 'ceg', 'agceb', 'bafgde', 'cebda', 'fgbc', 'cebgaf', 'aedbgfc']
# ['dfegac', 'aegbf', '1', '7', 'agceb', 'bafgde', 'cebda', '4', 'cebgaf', '8']
#
# ['acdfg', 'egd', 'fcge', 'fecdga', 'ecbfgad', 'eg', 'aedcb', 'eadcg', 'gfebad', 'adcfgb']
# ['acdfg', '7', '4', 'fecdga', '8', '1', 'aedcb', 'eadcg', 'gfebad', 'adcfgb']
#
# ['fcbadg', 'faebdc', 'ga', 'edga', 'fcegb', 'geadbf', 'gefab', 'bafde', 'afg', 'dcegbfa']
# ['fcbadg', 'faebdc', '1', '4', 'fcegb', 'geadbf', 'gefab', 'bafde', '7', '8']
#
# ['fbge', 'bfeacg', 'edabc', 'dgbfca', 'egdacf', 'beacg', 'gae', 'fceabgd', 'ge', 'fcabg']
# ['4', 'bfeacg', 'edabc', 'dgbfca', 'egdacf', 'beacg', '7', '8', '1', 'fcabg']
#
# ['cbe', 'fedgb', 'aedc', 'ecbfga', 'ec', 'dabgc', 'bfegdca', 'degbc', 'cgafbd', 'bdeagc']
# ['7', 'fedgb', '4', 'ecbfga', '1', 'dabgc', '8', 'degbc', 'cgafbd', 'bdeagc']
#
# ['gbdc', 'cb', 'edcfa', 'bagfd', 'agfedbc', 'agfbde', 'dfcab', 'cfb', 'gebafc', 'cagdbf']
# ['4', '1', 'edcfa', 'bagfd', '8', 'agfbde', 'dfcab', '7', 'gebafc', 'cagdbf']
#
# ['bgdae', 'fbagde', 'cegdbfa', 'aegfb', 'fb', 'dbfe', 'gbfdca', 'ecdabg', 'fgb', 'agecf']
# ['bgdae', 'fbagde', '8', 'aegfb', '1', '4', 'gbfdca', 'ecdabg', '7', 'agecf']
#
# ['bfacdg', 'ebcfda', 'cgdfeb', 'edbfgca', 'feadg', 'cfa', 'gabc', 'cgdaf', 'ca', 'cfbdg']
# ['bfacdg', 'ebcfda', 'cgdfeb', '8', 'feadg', '7', '4', 'cgdaf', '1', 'cfbdg']
#
# ['cgedba', 'abcfge', 'ade', 'fgdbae', 'edgaf', 'egbaf', 'edfabcg', 'bfde', 'ed', 'gcadf']
# ['cgedba', 'abcfge', '7', 'fgdbae', 'edgaf', 'egbaf', '8', '4', '1', 'gcadf']
#
# ['fbdcea', 'bgdcf', 'abfcgd', 'gcab', 'dcgbefa', 'dafcb', 'afbgde', 'fgedc', 'gdb', 'bg']
# ['fbdcea', 'bgdcf', 'abfcgd', '4', '8', 'dafcb', 'afbgde', 'fgedc', '7', '1']
#
# ['ebdf', 'dcafgb', 'afdecg', 'ebgca', 'adbfg', 'fe', 'efg', 'bcfdage', 'eabfg', 'agbfde']
# ['4', 'dcafgb', 'afdecg', 'ebgca', 'adbfg', '1', '7', '8', 'eabfg', 'agbfde']
#
# ['daebc', 'bedcfa', 'def', 'eacfg', 'eafdcbg', 'bcdf', 'edgabc', 'df', 'dfcea', 'gaedfb']
# ['daebc', 'bedcfa', '7', 'eacfg', '8', '4', 'edgabc', '1', 'dfcea', 'gaedfb']
#
# ['gf', 'gdcf', 'cdabf', 'bceadfg', 'dfcgba', 'cbagfe', 'gdeba', 'fbdag', 'gfa', 'dbefac']
# ['1', '4', 'cdabf', '8', 'dfcgba', 'cbagfe', 'gdeba', 'fbdag', '7', 'dbefac']
#
# ['ced', 'edcgabf', 'dgfceb', 'cdbg', 'fbceag', 'daefg', 'ecdfg', 'cd', 'cfbge', 'cabfed']
# ['7', '8', 'dgfceb', '4', 'fbceag', 'daefg', 'ecdfg', '1', 'cfbge', 'cabfed']
#
# Sum of all output values: 1063760
